# %%
import pandas as pd
import seaborn as sns 
import matplotlib as mat
import numpy as np
import matplotlib.pyplot as plt
#importing libraries

# %%
quality = pd.read_csv('winequality.csv') 
#imporing csv file

# %%
quality.shape
#shows no of row and colums
# Out:
# (6497, 12)

# %%
quality.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
quality.count()
# Out:
# fixed acidity           6497
# volatile acidity        6497
# citric acid             6497
# residual sugar          6497
# chlorides               6497
# free sulfur dioxide     6497
# total sulfur dioxide    6497
# density                 6497
# pH                      6497
# sulphates               6497
# alcohol                 6497
# quality                 6497
# dtype: int64

# %%
quality.index
# Out:
# RangeIndex(start=0, stop=6497, step=1)

# %%
quality.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
quality.pH
#shows only pH value
# Out:
# 0       3.51
# 1       3.20
# 2       3.26
# 3       3.16
# 4       3.51
# 5       3.51
# 6       3.30
# 7       3.39
# 8       3.36
# 9       3.35
# 10      3.28
# 11      3.35
# 12      3.58
# 13      3.26
# 14      3.16
# 15      3.17
# 16      3.30
# 17      3.11
# 18      3.38
# 19      3.04
# 20      3.39
# 21      3.52
# 22      3.17
# 23      3.17
# 24      3.43
# 25      3.34
# 26      3.28
# 27      3.17
# 28      3.47
# 29      3.38
#         ...
# 6467    3.31
# 6468    3.19
# 6469    3.15
# 6470    3.37
# 6471    3.14
# 6472    3.33
# 6473    3.49
# 6474    3.12
# 6475    3.36
# 6476    3.25
# 6477    3.24
# 6478    3.15
# 6479    3.15
# 6480    3.07
# 6481    3.26
# 6482    3.27
# 6483    3.14
# 6484    3.15
# 6485    3.21
# 6486    3.04
# 6487    3.04
# 6488    3.07
# 6489    3.06
# 6490    3.24
# 6491    3.29
# 6492    3.27
# 6493    3.15
# 6494    2.99
# 6495    3.34
# 6496    3.26
# Name: pH, Length: 6497, dtype: float64

# %%
quality.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
quality.tail(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 6492     11.2        6
# ...

# %%
quality[['citric acid','chlorides']]
# Out:
#       citric acid  chlorides
# 0            0.00      0.076
# 1            0.00      0.098
# 2            0.04      0.092
# 3            0.56      0.075
# 4            0.00      0.076
# 5            0.00      0.075
# 6            0.06      0.069
# 7            0.00      0.065
# 8            0.02      0.073
# 9            0.36      0.071
# 10           0.08      0.097
# 11           0.36      0.071
# 12           0.00      0.089
# 13           0.29      0.114
# 14           0.18      0.176
# 15           0.19      0.170
# 16           0.56      0.092
# 17           0.28      0.368
# 18           0.08      0.086
# 19           0.51      0.341
# 20           0.48      0.077
# 21           0.31      0.082
# 22           0.21      0.106
# 23           0.11      0.084
# 24           0.14      0.085
# 25           0.16      0.080
# 26           0.24      0.080
# 27           0.21      0.106
# 28           0.00      0.080
# 29           0.00      0.082
# ...           ...        ...
# ...

# %%
len(quality)
# Out:
# 6497

# %%
quality.quality.unique()
#show unique values in the column
# Out:
# array([5, 6, 7, 4, 8, 3, 9], dtype=int64)

# %%
quality['pH'].nunique()
#no of unique values in the column
# Out:
# 108

# %%
set(quality['pH'])
# Out:
# {2.72,
#  2.74,
#  2.77,
#  2.79,
#  2.8,
#  2.82,
#  2.83,
#  2.84,
#  2.85,
#  2.86,
#  2.87,
#  2.88,
#  2.89,
#  2.9,
#  2.91,
#  2.92,
#  2.93,
#  2.94,
#  2.95,
#  2.96,
#  2.97,
#  2.98,
#  2.99,
#  3.0,
#  3.01,
#  3.02,
#  3.03,
#  3.04,
#  3.05,
#  3.06,
#  3.07,
#  3.08,
#  3.09,
#  3.1,
#  3.11,
#  3.12,
#  3.13,
#  3.14,
#  3.15,
#  3.16,
#  3.17,
#  3.18,
#  3.19,
#  3.2,
#  3.21,
#  3.22,
#  3.23,
#  3.24,
#  3.25,
#  3.26,
#  3.27,
#  3.28,
#  3.29,
#  3.3,
#  3.31,
#  3.32,
#  3.33,
#  3.34,
#  3.35,
#  3.36,
#  3.37,
#  3.38,
#  3.39,
#  3.4,
#  3.41,
#  3.42,
#  3.43,
#  3.44,
#  3.45,
#  3.46,
#  3.47,
#  3.48,
#  3.49,
#  3.5,
#  3.51,
#  3.52,
#  3.53,
#  3.54,
#  3.55,
#  3.56,
#  3.57,
#  3.58,
#  3.59,
#  3.6,
#  3.61,
#  3.62,
#  3.63,
#  3.64,
#  3.65,
#  3.66,
#  3.67,
#  3.68,
#  3.69,
#  3.7,
#  3.71,
#  3.72,
#  3.74,
#  3.75,
#  3.76,
#  3.77,
#  3.78,
#  3.79,
#  3.8,
#  3.81,
#  3.82,
#  3.85,
#  3.9,
#  4.01}

# %%
quality['quality'] >=6
#condition >=6
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6       False
# 7        True
# 8        True
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16       True
# 17      False
# 18      False
# 19       True
# 20       True
# 21      False
# 22      False
# 23      False
# 24       True
# 25      False
# 26      False
# 27      False
# 28      False
# 29       True
#         ...
# 6467     True
# 6468     True
# 6469     True
# 6470     True
# 6471    False
# 6472     True
# 6473     True
# 6474     True
# 6475     True
# 6476    False
# 6477    False
# 6478     True
# 6479     True
# 6480     True
# 6481    False
# 6482     True
# 6483    False
# 6484     True
# 6485     True
# 6486     True
# 6487    False
# 6488     True
# 6489     True
# 6490     True
# 6491    False
# 6492     True
# 6493    False
# 6494     True
# 6495     True
# 6496     True
# ...

# %%
quality[(quality['quality'] >=6)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2             0.280         0.56            1.90      0.075
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 16              8.5             0.280         0.56            1.80      0.092
# 19              7.9             0.320         0.51            1.80      0.341
# 20              8.9             0.220         0.48            1.80      0.077
# 24              6.9             0.400         0.14            2.40      0.085
# 29              7.8             0.645         0.00            2.00      0.082
# 31              6.9             0.685         0.00            2.50      0.105
# 33              6.9             0.605         0.12           10.70      0.073
# 35              7.8             0.645         0.00            5.50      0.086
# ...

# %%
quality[~(quality['quality'] >=6)]
# ~not
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 9               7.5             0.500         0.36            6.10      0.071
# 10              6.7             0.580         0.08            1.80      0.097
# 11              7.5             0.500         0.36            6.10      0.071
# 12              5.6             0.615         0.00            1.60      0.089
# 13              7.8             0.610         0.29            1.60      0.114
# ...

# %%
quality[(quality['quality'] >=6) & (quality['pH'] >=3.8)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 95              4.7              0.60         0.17            2.30      0.058
# 695             5.1              0.47         0.02            1.30      0.034
# 1316            5.4              0.74         0.00            1.20      0.041
# 1321            5.0              0.74         0.00            1.20      0.041
# 2849            5.3              0.26         0.23            5.15      0.034
# 2854            6.4              0.22         0.34            1.80      0.057
# 3635            5.7              0.27         0.32            1.20      0.046
# 4370            6.3              0.20         0.24            1.70      0.052
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 95                   17.0                 106.0  0.99320  3.85       0.60
# 695                  18.0                  44.0  0.99210  3.90       0.62
# ...

# %%
quality.groupby(['quality']).groups
# Out:
# {3: Int64Index([ 459,  517,  690,  832,  899, 1299, 1374, 1469, 1478, 1505, 1850,
#              1852, 1893, 2044, 2339, 2472, 2633, 2828, 3016, 3083, 3287, 3530,
#              3649, 3972, 4686, 4864, 4906, 5008, 5409, 6344],
#             dtype='int64'),
#  4: Int64Index([  18,   38,   41,   45,   73,   79,   94,  151,  161,  167,
#              ...
#              6082, 6107, 6208, 6279, 6285, 6373, 6378, 6403, 6438, 6477],
#             dtype='int64', length=216),
#  5: Int64Index([   0,    1,    2,    4,    5,    6,    9,   10,   11,   12,
#              ...
#              6452, 6457, 6463, 6471, 6476, 6481, 6483, 6487, 6491, 6493],
#             dtype='int64', length=2138),
#  6: Int64Index([   3,   19,   20,   24,   29,   31,   33,   35,   36,   42,
#              ...
#              6479, 6480, 6482, 6484, 6488, 6489, 6490, 6492, 6494, 6496],
#             dtype='int64', length=2836),
#  7: Int64Index([   7,    8,   16,   37,   62,  128,  198,  200,  205,  206,
# ...

# %%
quality.iloc[3:11,4:7] 
#integer location indexing
# Out:
#     chlorides  free sulfur dioxide  total sulfur dioxide
# 3       0.075                 17.0                  60.0
# 4       0.076                 11.0                  34.0
# 5       0.075                 13.0                  40.0
# 6       0.069                 15.0                  59.0
# 7       0.065                 15.0                  21.0
# 8       0.073                  9.0                  18.0
# 9       0.071                 17.0                 102.0
# 10      0.097                 15.0                  65.0

# %%
quality.loc[4:8,"chlorides":"free sulfur dioxide"]
# Out:
#    chlorides  free sulfur dioxide
# 4      0.076                 11.0
# 5      0.075                 13.0
# 6      0.069                 15.0
# 7      0.065                 15.0
# 8      0.073                  9.0

# %%
quality[['pH', 'volatile acidity', 'quality']].loc[quality['quality'].isin(['7','8'])].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1272 entries, 7 to 6495
# Data columns (total 3 columns):
# pH                  1272 non-null float64
# volatile acidity    1272 non-null float64
# quality             1272 non-null int64
# dtypes: float64(2), int64(1)
# memory usage: 39.8 KB

# %%
qualitya = quality.set_index(['pH'])
qualitya
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 3.51            7.4             0.700         0.00            1.90      0.076
# 3.20            7.8             0.880         0.00            2.60      0.098
# 3.26            7.8             0.760         0.04            2.30      0.092
# 3.16           11.2             0.280         0.56            1.90      0.075
# 3.51            7.4             0.700         0.00            1.90      0.076
# 3.51            7.4             0.660         0.00            1.80      0.075
# 3.30            7.9             0.600         0.06            1.60      0.069
# 3.39            7.3             0.650         0.00            1.20      0.065
# 3.36            7.8             0.580         0.02            2.00      0.073
# 3.35            7.5             0.500         0.36            6.10      0.071
# 3.28            6.7             0.580         0.08            1.80      0.097
# ...

# %%
qualitya.sort_index(inplace = True) 
qualitya
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 2.72           10.0             0.230         0.27           14.10      0.033
# 2.74            9.2             0.520         1.00            3.40      0.610
# 2.74            9.7             0.240         0.45            1.20      0.033
# 2.77            9.9             0.490         0.23            2.40      0.087
# 2.79            7.4             0.200         0.35            6.10      0.025
# 2.79            8.5             0.170         0.31            1.00      0.024
# 2.79            8.5             0.170         0.31            1.00      0.024
# 2.80            8.1             0.120         0.38            0.90      0.034
# 2.80            6.9             0.230         0.35            6.90      0.030
# 2.80            9.6             0.210         0.28            1.20      0.038
# 2.82            7.0             0.360         0.25            5.70      0.015
# ...

# %%
quality.describe()
#mean=average
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
total = quality.isnull().sum().sort_values(ascending=False)
percent = (quality.isnull().sum()/quality.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
print(missing_data)
# Out:
#                       Total  Percent
# quality                   0      0.0
# alcohol                   0      0.0
# sulphates                 0      0.0
# pH                        0      0.0
# density                   0      0.0
# total sulfur dioxide      0      0.0
# free sulfur dioxide       0      0.0
# chlorides                 0      0.0
# residual sugar            0      0.0
# citric acid               0      0.0
# volatile acidity          0      0.0
# fixed acidity             0      0.0

# %%
quality.isnull().any()
#return false only when there is no null value in the dateset
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %%
n_wines = quality.shape[0]


quality_above_6 = quality.loc[(quality['quality'] > 6)]
n_above_6 = quality_above_6.shape[0]


quality_below_5 = quality.loc[(quality['quality'] < 5)]
n_below_5 = quality_below_5.shape[0]


quality_between_5 = quality.loc[(quality['quality'] >= 5) & (quality['quality'] <= 6)]
n_between_5 = quality_between_5.shape[0]


greater_percent = n_above_6*100/n_wines


print("Total number of wine quality: {}".format(n_wines))
print("Wines with rating 7 and above: {}".format(n_above_6))
print("Wines with rating less than 5: {}".format(n_below_5))
print("Wines with rating 5 and 6: {}".format(n_between_5))
print("Percentage of wines with quality 7 and above: {:.2f}%".format(greater_percent))


display(np.round(quality.describe()))
# Out:
# Total number of wine quality: 6497
# Wines with rating 7 and above: 1277
# Wines with rating less than 5: 246
# Wines with rating 5 and 6: 4974
# Percentage of wines with quality 7 and above: 19.66%
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count         6497.0            6497.0       6497.0          6497.0
# mean             7.0               0.0          0.0             5.0
# std              1.0               0.0          0.0             5.0
# min              4.0               0.0          0.0             1.0
# 25%              6.0               0.0          0.0             2.0
# 50%              7.0               0.0          0.0             3.0
# 75%              8.0               0.0          0.0             8.0
# max             16.0               2.0          2.0            66.0
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count     6497.0               6497.0                6497.0   6497.0  6497.0
# ...

# %%
quality['pH'].value_counts().head(10).plot.bar()

# %%
quality['pH'].plot.hist()

# %%
quality['quality'].value_counts().sort_index().plot.bar()

# %%
plt.figure(figsize=(10,5))
sns.countplot('quality',data = quality, order = quality['quality'].value_counts().index,palette="PuBuGn_d")
plt.title("quality Counts",fontsize=18,fontweight="bold")
plt.xlabel('quality')
plt.ylabel('Frequency')
plt.show()

# %%
quality['pH'].value_counts().head(10).plot.line()

# %%
quality[quality['pH'] > 3.6]['pH'].plot.hist()

# %%
quality['pH'].value_counts().sort_index().plot.line()

# %%
quality[['pH','quality']].plot.scatter(x='pH', y='quality')

# %%
quality[quality['pH'] <3.6].sample(50).plot.scatter(x='pH', y='quality')

# %%
quality[(quality['pH'] <3.6) & (quality['quality'] > 6)].sample(50).plot.scatter(x='pH', y='quality')

# %%
sns.set(color_codes=True)                                                # Plot a histogram of the respondents' ages (remove any NaN values)
sns.set_palette(sns.color_palette("muted"))

sns.distplot(quality["pH"].dropna());

# %%
quality[['pH','quality']].plot.hexbin(x='pH', y='quality', gridsize=10)

# %%
quality[['pH','quality']].plot.bar(stacked=True)

# %%
quality.plot.line()

# %%
g = sns.pairplot(quality)
#to find the co-relation in-between the column

# %%
plt.figure(figsize=(9,5))
sns.heatmap(quality.corr(),annot=True, linewidth=0.5, cmap='coolwarm')
#heatmap to find the co-relation of the column

# %%
correlation = quality.corr()
# display(correlation)
plt.figure(figsize=(14, 12))
heatmap = sns.heatmap(correlation, annot=True, linewidths=0, vmin=-1, cmap="RdBu_r")

# %%
correlations = quality.corr()['quality']
print(correlations)
#+ve value influence more the output (near to 0)
# Out:
# fixed acidity          -0.076743
# volatile acidity       -0.265699
# citric acid             0.085532
# residual sugar         -0.036980
# chlorides              -0.200666
# free sulfur dioxide     0.055463
# total sulfur dioxide   -0.041385
# density                -0.305858
# pH                      0.019506
# sulphates               0.038485
# alcohol                 0.444319
# quality                 1.000000
# Name: quality, dtype: float64

# %%
sns.pairplot(quality[['free sulfur dioxide', 'citric acid', 'sulphates', 'alcohol','quality']], hue="quality",palette="viridis",size=5)
# Out:
# C:\Users\Bharath\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
fixedAcidity_quality = quality[['pH', 'fixed acidity']]

gridA = sns.JointGrid(x="fixed acidity", y="pH", data=fixedAcidity_quality, size=6)

gridA = gridA.plot_joint(sns.regplot, scatter_kws={"s": 10})

gridA = gridA.plot_marginals(sns.distplot)
#We can see that, as fixed acidity levels increase, the pH levels drop
# Out:
# C:\Users\Bharath\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1672: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
quality_citricAcid = quality[['citric acid', 'fixed acidity']]
g = sns.JointGrid(x="fixed acidity", y="citric acid", data=quality_citricAcid, size=6)
g = g.plot_joint(sns.regplot, scatter_kws={"s": 10})
g = g.plot_marginals(sns.distplot)
# Out:
# C:\Users\Bharath\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1672: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
fig, axs = plt.subplots(ncols=1,figsize=(10,6))
sns.barplot(x='quality', y='volatile acidity', data=quality, ax=axs)
plt.title('quality VS volatile acidity')

plt.tight_layout()
plt.show()
plt.gcf().clear()
#linearity is over there which is good

# %%
fig, axs = plt.subplots(ncols=1,figsize=(10,6))
sns.barplot(x='quality', y='residual sugar', data=quality, ax=axs)
plt.title('quality VS residual sugar')

plt.tight_layout()
plt.show()
plt.gcf().clear()
#linearity is not over there which is bad

# %%
fig, axs = plt.subplots(ncols=1,figsize=(10,6))
sns.barplot(x='quality', y='sulphates', data=quality, ax=axs)
plt.title('quality VS sulphate')

plt.tight_layout()
plt.show()
plt.gcf().clear()

# %%
fig, axs = plt.subplots(ncols=1,figsize=(10,6))
sns.barplot(x='quality', y='citric acid', data=quality, ax=axs)
plt.title('quality VS citric acid')

plt.tight_layout()
plt.show()
plt.gcf().clear()

# %%
fig, axs = plt.subplots(ncols=1,figsize=(10,6))
sns.barplot(x='quality', y='alcohol', data=quality, ax=axs)
plt.title('quality VS alcohol')

plt.tight_layout()
plt.show()
plt.gcf().clear()

# %%
qualityb = ['fixed acidity', 'citric acid', 'sulphates', 'alcohol']
sns.pairplot(quality, x_vars = qualityb, y_vars = 'quality', size=4)
sns.plt.show()
# Out:
# C:\Users\Bharath\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-2b07de9a5fbf> in <module>
#       1 qualityb = ['fixed acidity', 'citric acid', 'sulphates', 'alcohol']
#       2 sns.pairplot(quality, x_vars = qualityb, y_vars = 'quality', size=4)
# ----> 3 sns.plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'plt'

# %%
sns.lmplot(x='pH', y='fixed acidity', hue='quality', 
           data=quality.loc[quality['quality'].isin(['3', '4','5', '6','7', '8','9'])], 
           fit_reg=False)

# %%
sns.lmplot(x='pH', y='fixed acidity', hue='quality', 
           data=quality.loc[quality['quality'].isin(['7', '8','9'])], 
           fit_reg=False)

# %%
sns.lmplot(x='pH', y='fixed acidity',markers=['*', 'x', 'o'], hue='quality', 
           data=quality.loc[quality['quality'].isin(['7', '8','9'])], 
           fit_reg=False)

# %%
sns.lmplot(x='pH', y='citric acid', hue='quality', 
           data=quality.loc[quality['quality'].isin(['7', '8','9'])], 
           fit_reg=False)

# %%
fig,ax =plt.subplots(figsize=(8,6))
sns.countplot(data = quality.head(20),x = 'pH', hue='quality')
plt.title('pH vs quality')
# Out:
# Text(0.5, 1.0, 'pH vs quality')

# %%
quality[['quality','sulphates']].plot.scatter(x='quality', y='sulphates')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
for feature in quality.keys():
   
    Q1 = np.percentile(quality[feature], q=25)
    
   
    Q3 = np.percentile(quality[feature], q=75)
    
    
    interquartile_range = Q3 - Q1
    step = 1.5 * interquartile_range
    
    
    print("quality points considered outliers for the feature '{}':".format(feature))
    display(quality[~((quality[feature] >= Q1 - step) & (quality[feature] <= Q3 + step))])
    
    
    outliers = []
    
    good_quality = quality.drop(quality.index[outliers]).reset_index(drop = True)
    
    #outlinier=an outlier is a data point that is significantly distant from most other data points.
# Out:
# quality points considered outliers for the feature 'fixed acidity':
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2             0.280         0.56            1.90      0.075
# 56             10.2             0.420         0.57            3.40      0.070
# 74              9.7             0.320         0.54            2.50      0.094
# 113            10.1             0.310         0.44            2.30      0.080
# 197            11.5             0.300         0.60            2.00      0.067
# 205            12.8             0.300         0.74            2.60      0.095
# 206            12.8             0.300         0.74            2.60      0.095
# 209            11.0             0.300         0.58            2.10      0.054
# 210             9.7             0.530         0.60            2.00      0.039
# 212            11.6             0.440         0.64            2.10      0.059
# ...
